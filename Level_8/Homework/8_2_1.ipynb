# %% [markdown]
# # Tabular Data

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### Exercise 1
# Use the yfinance library to download two years of stock data for your favorite stock ticker into a DataFrame and display it.

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import yfinance as yf

wkhs = yf.Ticker("WKHS")
wkhsData = wkhs.history(period="max")
wkhsData
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2010-06-02  10.100000  10.100000  10.100000  10.100000       100          0
# 2010-06-03   7.500000  10.100000   7.500000  10.100000       500          0
# 2010-06-04  10.100000  10.100000  10.100000  10.100000         0          0
# 2010-06-07   8.000000   8.000000   8.000000   8.000000         0          0
# 2010-06-08   8.000000   8.000000   8.000000   8.000000         0          0
# ...               ...        ...        ...        ...       ...        ...
# 2020-10-12  27.975000  30.590000  26.280001  26.580000  79836400          0
# 2020-10-13  25.415001  25.879999  22.370001  23.629999  62422500          0
# 2020-10-14  24.059999  24.170000  22.799999  22.920000  25564000          0
# 2020-10-15  22.389999  22.832001  21.510000  22.299999  17449500          0
# 2020-10-16  22.840000  23.850000  22.410000  22.809999  19819700          0
#
#             Stock Splits
# Date
# 2010-06-02           0.0
# 2010-06-03           0.0
# 2010-06-04           0.0
# 2010-06-07           0.0
# 2010-06-08           0.0
# ...                  ...
# 2020-10-12           0.0
# 2020-10-13           0.0
# 2020-10-14           0.0
# 2020-10-15           0.0
# 2020-10-16           0.0
#
# [2614 rows x 7 columns]
