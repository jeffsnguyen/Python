# %% [markdown]
# # Tabular Data

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### Exercise 1
# Use the yfinance library to download two years of stock data for your favorite stock ticker into a DataFrame and display it.

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import yfinance as yf

aapl = yf.Ticker('AAPL')
aaplData = aapl.history(period='max')
aaplData
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.101261    0.101701    0.101261    0.101261  469033600
# 1980-12-15    0.096418    0.096418    0.095978    0.095978  175884800
# 1980-12-16    0.089374    0.089374    0.088934    0.088934  105728000
# 1980-12-17    0.091135    0.091575    0.091135    0.091135   86441600
# 1980-12-18    0.093777    0.094217    0.093777    0.093777   73449600
# ...                ...         ...         ...         ...        ...
# 2020-10-19  119.959999  120.419998  115.660004  115.980003  120639300
# 2020-10-20  116.199997  118.980003  115.629997  117.510002  124423700
# 2020-10-21  116.669998  118.709999  116.449997  116.870003   89946000
# 2020-10-22  117.449997  118.040001  114.589996  115.750000  101709700
# 2020-10-23  116.389999  116.550003  114.279999  115.040001   79629035
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# 1980-12-16        0.0           0.0
# 1980-12-17        0.0           0.0
# 1980-12-18        0.0           0.0
# ...               ...           ...
# 2020-10-19        0.0           0.0
# 2020-10-20        0.0           0.0
# 2020-10-21        0.0           0.0
# 2020-10-22        0.0           0.0
# 2020-10-23        0.0           0.0
#
# [10052 rows x 7 columns]
