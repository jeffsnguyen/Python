# %% [markdown]
# # CSV

# %%
import pandas as pd
pd.read_csv('tsla_data.csv')
# Out:
#             Date        Open        High         Low       Close    Volume  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000  93831500
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000  85935500
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000  41094000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000  25699000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000  34334500
# ...          ...         ...         ...         ...         ...       ...
# 2589  2020-10-09  430.130005  434.589996  426.459991  434.000000  28925700
# 2590  2020-10-12  442.000000  448.739990  438.579987  442.299988  38791100
# 2591  2020-10-13  443.350006  448.890015  436.600006  446.649994  34463700
# 2592  2020-10-14  449.779999  465.899994  447.350006  461.299988  48045400
# 2593  2020-10-15  450.309998  456.570007  442.500000  448.880005  35554200
#
#       Dividends  Stock Splits
# 0             0           0.0
# ...

# %% [markdown]
# # yfinance

# %%
import yfinance as yf
tsla = yf.Ticker("TSLA")

# %%
# dir(tsla)
x = tsla.history(period="max")
x
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2010-06-29    3.800000    5.000000    3.508000    4.778000  93831500
# 2010-06-30    5.158000    6.084000    4.660000    4.766000  85935500
# 2010-07-01    5.000000    5.184000    4.054000    4.392000  41094000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000  25699000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000  34334500
# ...                ...         ...         ...         ...       ...
# 2020-10-09  430.130005  434.589996  426.459991  434.000000  28925700
# 2020-10-12  442.000000  448.739990  438.579987  442.299988  38791100
# 2020-10-13  443.350006  448.890015  436.600006  446.649994  34463700
# 2020-10-14  449.779999  465.899994  447.350006  461.299988  48045400
# 2020-10-15  450.309998  456.570007  442.500000  448.880005  35554200
#
#             Dividends  Stock Splits
# Date
# 2010-06-29          0           0.0
# 2010-06-30          0           0.0
# ...

# %%
x.to_csv('tsla_data.csv')

# %%
tsla.institutional_holders
# Out:
#                         Holder    Shares Date Reported   % Out        Value
# 0  Baillie Gifford and Company  58856065    2020-06-29  0.0635  12710673509
# 1      Capital World Investors  53390465    2020-06-29  0.0576  11530311602
# 2   Vanguard Group, Inc. (The)  44264185    2020-06-29  0.0478   9559381920
# 3               Blackrock Inc.  38598840    2020-06-29  0.0416   8335882684
# 4                     FMR, LLC  23546700    2020-06-29  0.0254   5085192425
# 5      Jennison Associates LLC  19343710    2020-06-29  0.0209   4177506299
# 6     State Street Corporation  15835650    2020-06-29  0.0171   3419898645
# 7    JP Morgan Chase & Company  13754295    2020-06-29  0.0148   2970405056
# 8    Goldman Sachs Group, Inc.   9942455    2020-06-29  0.0107   2147192466
# 9                   BAMCO Inc.   8085050    2020-06-29  0.0087   1746063568

# %%
tsla.major_holders
# Out:
#         0                                      1
# 0  20.51%        % of Shares Held by All Insider
# 1  57.93%       % of Shares Held by Institutions
# 2  72.87%        % of Float Held by Institutions
# 3    1319  Number of Institutions Holding Shares

# %%
tickers = yf.Tickers('msft aapl goog')

# %%
tickers.history().head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#                  Close                          Dividends            \
#                   AAPL         GOOG        MSFT      AAPL GOOG MSFT
# Date
# 2020-09-16  112.129997  1520.900024  205.050003         0    0    0
# 2020-09-17  110.339996  1495.530029  202.910004         0    0    0
# 2020-09-18  106.839996  1459.989990  200.389999         0    0    0
# 2020-09-21  110.080002  1431.160034  202.539993         0    0    0
# 2020-09-22  111.809998  1465.459961  207.419998         0    0    0
#
#                   High                                  Low  ...              \
#                   AAPL         GOOG        MSFT        AAPL  ...        MSFT
# Date                                                         ...
# 2020-09-16  116.000000  1562.000000  210.649994  112.040001  ...  204.639999
# 2020-09-17  112.199997  1508.297974  204.330002  108.709999  ...  199.960007
# ...

# %% [markdown]
# # quandl

# %%
import quandl
quandl.ApiConfig.api_key = ''
mydata = quandl.get_table('ZACKS/FC', ticker='AAPL')

display(mydata)
# Out:
#      m_ticker ticker  comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 1        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 2        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 3        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 4        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
#
#      per_end_date per_type per_code  per_fisc_year  ...  \
# None                                                ...
# 0      2018-09-30        A     None           2018  ...
# 1      2018-03-31        Q     None           2018  ...
# 2      2018-06-30        Q     None           2018  ...
# 3      2018-09-30        Q     None           2018  ...
# 4      2018-12-31        Q     None           2019  ...
#
#       stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None
# 0                       NaN                         NaN
# ...

# %%
display(quandl.get('WIKI/TSLA', row=5))
# Out:
#               Open      High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0          0.0
# 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0          0.0
# 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0          0.0
# 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0          0.0
# 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0          0.0
# ...            ...       ...     ...     ...         ...          ...
# 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0          0.0
# 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0          0.0
# 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0          0.0
# 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0          0.0
# 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# ...

# %% [markdown]
# # DataReader

# %%
import pandas_datareader as pdr

# %%
tsla = pdr.DataReader('TSLA',
                      start='2020-1-1',
                      end='2020-12-31',
                      data_source='yahoo')['Adj Close']
tsla
# Out:
# Date
# 2020-01-02     86.052002
# 2020-01-03     88.601997
# 2020-01-06     90.307999
# 2020-01-07     93.811996
# 2020-01-08     98.428001
#                  ...
# 2020-10-09    434.000000
# 2020-10-12    442.299988
# 2020-10-13    446.649994
# 2020-10-14    461.299988
# 2020-10-15    448.880005
# Name: Adj Close, Length: 200, dtype: float64

# %%
import os

import pandas_datareader.data as web

f = web.DataReader('USD/JPY', 'av-forex',
                  api_key=os.getenv('ALPHAVANTAGE_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0f71e8dcaa04> in <module>
#       3 import pandas_datareader.data as web
#       4
# ----> 5 f = web.DataReader('USD/JPY', 'av-forex',
#       6                   api_key=os.getenv('ALPHAVANTAGE_API_KEY'))
#
# D:\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# D:\anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     551
#     552     elif data_source == "av-forex":
# --> 553         return AVForexReader(
#     554             symbols=name,
#     555             retry_count=retry_count,
#
# ...

# %% [markdown]
# # sportsreference

# %%
from sportsreference.nba.teams import Teams

teams = Teams()
for team in teams:
    print(team.name, team.abbreviation)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-35-535e3a79d039> in <module>
#       1 from sportsreference.nba.teams import Teams
#       2
# ----> 3 teams = Teams()
#       4 for team in teams:
#       5     print(team.name, team.abbreviation)
#
# D:\anaconda3\lib\site-packages\sportsreference\nba\teams.py in __init__(self, year)
#     589         self._teams = []
#     590
# --> 591         self._retrieve_all_teams(year)
#     592
#     593     def __getitem__(self, abbreviation):
#
# D:\anaconda3\lib\site-packages\sportsreference\nba\teams.py in _retrieve_all_teams(self, year)
#     716                utils._url_exists(SEASON_PAGE_URL % str(int(year) - 1)):
#     717                 year = str(int(year) - 1)
# --> 718         doc = pq(SEASON_PAGE_URL % year)
#     719         teams_list = utils._get_stats_table(doc, 'div#all_team-stats-base')
# ...
