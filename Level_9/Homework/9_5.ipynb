# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Exercise 5
# This exercise uses the derived data created in level 7, exercise 13. You should do the following:
# a. Plot cumulative PnL for each ticker from your portfolio, on the same plot. Hint: Use DataFrame pivoting functionality.
# b. Create a scatter plot of PnL per ticker, year 1 vs year 2. Use different color points for each ticker, and use alpha as appropriate.

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd

# Load data
scaffoldPortfolio = pd.read_csv('scaffoldPortfolio_data.csv', index_col=0).set_index('Date')
scaffoldPortfolio
# Out:
#            Ticker  Position                    Security SEC filings  \
# Date
# 2018-01-10    MMM   15000.0                  3M Company     reports
# 2018-01-11    ABT   20000.0         Abbott Laboratories     reports
# 2018-01-11    MMM   15000.0                  3M Company     reports
# 2018-01-12    ABT   20000.0         Abbott Laboratories     reports
# 2018-01-12    MMM   15000.0                  3M Company     reports
# ...           ...       ...                         ...         ...
# 2020-01-10   AMZN    6000.0             Amazon.com Inc.     reports
# 2020-01-10    MMM   42000.0                  3M Company     reports
# 2020-01-10   SCHW       0.0  Charles Schwab Corporation     reports
# 2020-01-10    YUM       0.0             Yum! Brands Inc     reports
# 2020-01-10    ZTS    5000.0                      Zoetis     reports
#
#                        GICS Sector                   GICS Sub-Industry  \
# Date
# 2018-01-10             Industrials            Industrial Conglomerates
# 2018-01-11             Health Care               Health Care Equipment
# 2018-01-11             Industrials            Industrial Conglomerates
# 2018-01-12             Health Care               Health Care Equipment
# 2018-01-12             Industrials            Industrial Conglomerates
# ...                            ...                                 ...
# 2020-01-10  Consumer Discretionary  Internet & Direct Marketing Retail
# 2020-01-10             Industrials            Industrial Conglomerates
# 2020-01-10              Financials      Investment Banking & Brokerage
# 2020-01-10  Consumer Discretionary                         Restaurants
# 2020-01-10             Health Care                     Pharmaceuticals
#
#                 Headquarters Location Date first added        CIK  Founded  \
# Date
# 2018-01-10        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2018-01-11    North Chicago, Illinois       1964-03-31     1800.0     1888
# 2018-01-11        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2018-01-12    North Chicago, Illinois       1964-03-31     1800.0     1888
# 2018-01-12        St. Paul, Minnesota       1976-08-09    66740.0     1902
# ...                               ...              ...        ...      ...
# 2020-01-10        Seattle, Washington       2005-11-18  1018724.0     1994
# 2020-01-10        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2020-01-10  San Francisco, California       1997-06-02   316709.0     1971
# 2020-01-10       Louisville, Kentucky       1997-10-06  1041061.0     1997
# 2020-01-10   Florham Park, New Jersey       2013-06-21  1555280.0     1952
#
#             ...         Open  Stock Splits     Volume  Daily Return  \
# Date        ...
# 2018-01-10  ...   220.860454           0.0  1640900.0      1.876795
# 2018-01-11  ...    56.042228           0.0  4240900.0     -0.731959
# 2018-01-11  ...   220.622226           0.0  1487700.0      1.895749
# 2018-01-12  ...    56.338434           0.0  6320900.0     -0.738628
# 2018-01-12  ...   222.757511           0.0  1974300.0      1.895828
# ...         ...          ...           ...        ...           ...
# 2020-01-10  ...  1905.369995           0.0  2853700.0      7.267550
# 2020-01-10  ...   176.605104           0.0  2103800.0      0.598660
# 2020-01-10  ...    47.448014           0.0  7452900.0     -0.469068
# 2020-01-10  ...   101.243774           0.0  1462400.0      0.266653
# 2020-01-10  ...   134.529294           0.0  1249000.0      1.737139
#
#             1-week MA Daily Return  Rolling Cumulative Volume     Daily P&L  \
# Date
# 2018-01-10                0.350461               1.640580e+13  28151.927647
# 2018-01-11                0.201628               1.640660e+13 -14639.173012
# 2018-01-11                0.353683               1.640774e+13  28436.232002
# 2018-01-12                0.205469               1.640853e+13 -14772.556368
# 2018-01-12                0.356432               1.640979e+13  28437.418212
# ...                            ...                        ...           ...
# 2020-01-10                1.952383               1.747607e+13  43605.302282
# 2020-01-10                0.252569               1.747692e+13  25143.699270
# 2020-01-10                0.057612               1.747724e+13           NaN
# 2020-01-10                0.134937               1.747750e+13           NaN
# 2020-01-10                0.468656               1.747751e+13   8685.693099
#
#             Cumulative Daily P&L  Cumulative Daily Portfolio P&L     Yield
# Date
# 2018-01-10          2.815193e+04                    28151.927647  1.876795
# 2018-01-11         -1.463917e+04                    13797.058990 -0.731959
# 2018-01-11          5.658816e+04                    13797.058990  1.895749
# 2018-01-12         -2.941173e+04                    13664.861844 -0.738628
# 2018-01-12          8.502558e+04                    13664.861844  1.895828
# ...                          ...                             ...       ...
# 2020-01-10          2.739225e+07                    86826.035921  7.267550
# 2020-01-10          2.156141e+07                    86826.035921  0.598660
# 2020-01-10         -5.382023e+05                    86826.035921       NaN
# 2020-01-10          8.360253e+05                    86826.035921       NaN
# 2020-01-10          3.261122e+06                    86826.035921  1.737139
#
# [3341 rows x 24 columns]

# %% [markdown]
# #### a. Plot cumulative PnL for each ticker from your portfolio, on the same plot. Hint: Use DataFrame pivoting functionality.

# %%
import matplotlib.pyplot as plt # Similar to Matlab style

fig, ax1 = plt.subplots(figsize=(10, 5), sharex=True)

for ticker in scaffoldPortfolio.Ticker.unique():
    data = scaffoldPortfolio[scaffoldPortfolio.Ticker == ticker]
    ax1.plot(data[['Cumulative Daily P&L']], label='%s' % ticker)

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# #### b. Create a scatter plot of PnL per ticker, year 1 vs year 2. Use different color points for each ticker, and use alpha as appropriate.

# %%
scaffoldPortfolio = scaffoldPortfolio.reset_index()

y1 = scaffoldPortfolio[scaffoldPortfolio['Date'] < '2019-03-27'].set_index('Date')
y2 = scaffoldPortfolio[scaffoldPortfolio['Date'] >= '2019-03-27'].set_index('Date')

fig, ax1 = plt.subplots(figsize=(10, 5), sharex=True)
#ax2 = ax1.twinx()

for ticker in scaffoldPortfolio.Ticker.unique():
    data_y1 = y1[y1.Ticker == ticker]
    data_y2 = y2[y2.Ticker == ticker]
    ax1.scatter(data_y1[['Daily P&L']], data_y2[['Daily P&L']], label='%s year 1' % ticker, alpha=0.2)

plt.show()
# Out:
#            Ticker  Position                    Security SEC filings  \
# Date
# 2018-01-10    MMM   15000.0                  3M Company     reports
# 2018-01-11    ABT   20000.0         Abbott Laboratories     reports
# 2018-01-11    MMM   15000.0                  3M Company     reports
# 2018-01-12    ABT   20000.0         Abbott Laboratories     reports
# 2018-01-12    MMM   15000.0                  3M Company     reports
# ...           ...       ...                         ...         ...
# 2019-03-26   AMZN    6000.0             Amazon.com Inc.     reports
# 2019-03-26    MMM   38000.0                  3M Company     reports
# 2019-03-26   SCHW   20000.0  Charles Schwab Corporation     reports
# 2019-03-26    YUM    7000.0             Yum! Brands Inc     reports
# 2019-03-26    ZTS    7000.0                      Zoetis     reports
#
#                        GICS Sector                   GICS Sub-Industry  \
# Date
# 2018-01-10             Industrials            Industrial Conglomerates
# 2018-01-11             Health Care               Health Care Equipment
# 2018-01-11             Industrials            Industrial Conglomerates
# 2018-01-12             Health Care               Health Care Equipment
# 2018-01-12             Industrials            Industrial Conglomerates
# ...                            ...                                 ...
# 2019-03-26  Consumer Discretionary  Internet & Direct Marketing Retail
# 2019-03-26             Industrials            Industrial Conglomerates
# 2019-03-26              Financials      Investment Banking & Brokerage
# 2019-03-26  Consumer Discretionary                         Restaurants
# 2019-03-26             Health Care                     Pharmaceuticals
#
#                 Headquarters Location Date first added        CIK  Founded  \
# Date
# 2018-01-10        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2018-01-11    North Chicago, Illinois       1964-03-31     1800.0     1888
# 2018-01-11        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2018-01-12    North Chicago, Illinois       1964-03-31     1800.0     1888
# 2018-01-12        St. Paul, Minnesota       1976-08-09    66740.0     1902
# ...                               ...              ...        ...      ...
# 2019-03-26        Seattle, Washington       2005-11-18  1018724.0     1994
# 2019-03-26        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2019-03-26  San Francisco, California       1997-06-02   316709.0     1971
# 2019-03-26       Louisville, Kentucky       1997-10-06  1041061.0     1997
# 2019-03-26   Florham Park, New Jersey       2013-06-21  1555280.0     1952
#
#             ...         Open  Stock Splits      Volume  Daily Return  \
# Date        ...
# 2018-01-10  ...   220.860454           0.0   1640900.0      1.876795
# 2018-01-11  ...    56.042228           0.0   4240900.0     -0.731959
# 2018-01-11  ...   220.622226           0.0   1487700.0      1.895749
# 2018-01-12  ...    56.338434           0.0   6320900.0     -0.738628
# 2018-01-12  ...   222.757511           0.0   1974300.0      1.895828
# ...         ...          ...           ...         ...           ...
# 2019-03-26  ...  1793.000000           0.0   4865900.0      8.431389
# 2019-03-26  ...   194.185868           0.0   1895600.0      1.184443
# 2019-03-26  ...    41.197461           0.0  10285400.0     -0.415367
# 2019-03-26  ...    96.512430           0.0   1361100.0      0.255519
# 2019-03-26  ...    97.550511           0.0   1795400.0      1.286328
#
#             1-week MA Daily Return  Rolling Cumulative Volume     Daily P&L  \
# Date
# 2018-01-10                0.350461               1.640580e+13  28151.927647
# 2018-01-11                0.201628               1.640660e+13 -14639.173012
# 2018-01-11                0.353683               1.640774e+13  28436.232002
# 2018-01-12                0.205469               1.640853e+13 -14772.556368
# 2018-01-12                0.356432               1.640979e+13  28437.418212
# ...                            ...                        ...           ...
# 2019-03-26                2.406588               1.709341e+13  50588.336124
# 2019-03-26                0.257275               1.709437e+13  45008.852319
# 2019-03-26                0.065736               1.709476e+13  -8307.331388
# 2019-03-26                0.139036               1.709503e+13   1788.635781
# 2019-03-26                0.343533               1.709503e+13   9004.293616
#
#             Cumulative Daily P&L  Cumulative Daily Portfolio P&L     Yield
# Date
# 2018-01-10          2.815193e+04                    28151.927647  1.876795
# 2018-01-11         -1.463917e+04                    13797.058990 -0.731959
# 2018-01-11          5.658816e+04                    13797.058990  1.895749
# 2018-01-12         -2.941173e+04                    13664.861844 -0.738628
# 2018-01-12          8.502558e+04                    13664.861844  1.895828
# ...                          ...                             ...       ...
# 2019-03-26          1.794808e+07                    99155.453848  8.431389
# 2019-03-26          1.599569e+07                    99155.453848  1.184443
# 2019-03-26         -1.824582e+05                    99155.453848 -0.415367
# 2019-03-26          8.307102e+05                    99155.453848  0.255519
# 2019-03-26          1.038395e+06                    99155.453848  1.286328
#
# [1677 rows x 24 columns]
#            Ticker  Position                    Security SEC filings  \
# Date
# 2019-03-27   AAPL    9000.0                  Apple Inc.     reports
# 2019-03-27    ABT   20000.0         Abbott Laboratories     reports
# 2019-03-27    ACN   20000.0               Accenture plc     reports
# 2019-03-27   AMZN    6000.0             Amazon.com Inc.     reports
# 2019-03-27    MMM   38000.0                  3M Company     reports
# ...           ...       ...                         ...         ...
# 2020-01-10   AMZN    6000.0             Amazon.com Inc.     reports
# 2020-01-10    MMM   42000.0                  3M Company     reports
# 2020-01-10   SCHW       0.0  Charles Schwab Corporation     reports
# 2020-01-10    YUM       0.0             Yum! Brands Inc     reports
# 2020-01-10    ZTS    5000.0                      Zoetis     reports
#
#                        GICS Sector  \
# Date
# 2019-03-27  Information Technology
# 2019-03-27             Health Care
# 2019-03-27  Information Technology
# 2019-03-27  Consumer Discretionary
# 2019-03-27             Industrials
# ...                            ...
# 2020-01-10  Consumer Discretionary
# 2020-01-10             Industrials
# 2020-01-10              Financials
# 2020-01-10  Consumer Discretionary
# 2020-01-10             Health Care
#
#                                      GICS Sub-Industry  \
# Date
# 2019-03-27  Technology Hardware, Storage & Peripherals
# 2019-03-27                       Health Care Equipment
# 2019-03-27              IT Consulting & Other Services
# 2019-03-27          Internet & Direct Marketing Retail
# 2019-03-27                    Industrial Conglomerates
# ...                                                ...
# 2020-01-10          Internet & Direct Marketing Retail
# 2020-01-10                    Industrial Conglomerates
# 2020-01-10              Investment Banking & Brokerage
# 2020-01-10                                 Restaurants
# 2020-01-10                             Pharmaceuticals
#
#                 Headquarters Location Date first added        CIK  Founded  \
# Date
# 2019-03-27      Cupertino, California       1982-11-30   320193.0     1977
# 2019-03-27    North Chicago, Illinois       1964-03-31     1800.0     1888
# 2019-03-27            Dublin, Ireland       2011-07-06  1467373.0     1989
# 2019-03-27        Seattle, Washington       2005-11-18  1018724.0     1994
# 2019-03-27        St. Paul, Minnesota       1976-08-09    66740.0     1902
# ...                               ...              ...        ...      ...
# 2020-01-10        Seattle, Washington       2005-11-18  1018724.0     1994
# 2020-01-10        St. Paul, Minnesota       1976-08-09    66740.0     1902
# 2020-01-10  San Francisco, California       1997-06-02   316709.0     1971
# 2020-01-10       Louisville, Kentucky       1997-10-06  1041061.0     1997
# 2020-01-10   Florham Park, New Jersey       2013-06-21  1555280.0     1952
#
#             ...         Open  Stock Splits       Volume  Daily Return  \
# Date        ...
# 2019-03-27  ...    46.368494           0.0  119393600.0     -0.720047
# 2019-03-27  ...    76.859743           0.0    4101900.0     -0.722866
# 2019-03-27  ...   162.313924           0.0    2376200.0      1.112337
# 2019-03-27  ...  1784.130005           0.0    4324800.0      8.382077
# 2019-03-27  ...   196.459264           0.0    2004000.0      1.199976
# ...         ...          ...           ...          ...           ...
# 2020-01-10  ...  1905.369995           0.0    2853700.0      7.267550
# 2020-01-10  ...   176.605104           0.0    2103800.0      0.598660
# 2020-01-10  ...    47.448014           0.0    7452900.0     -0.469068
# 2020-01-10  ...   101.243774           0.0    1462400.0      0.266653
# 2020-01-10  ...   134.529294           0.0    1249000.0      1.737139
#
#             1-week MA Daily Return  Rolling Cumulative Volume     Daily P&L  \
# Date
# 2019-03-27                0.834221               1.709516e+13  -6480.424159
# 2019-03-27                0.371418               1.709517e+13 -14457.320663
# 2019-03-27                0.737895               1.709517e+13  22246.737711
# 2019-03-27                2.412334               1.709532e+13  50292.460726
# 2019-03-27                0.257487               1.709634e+13  45599.069118
# ...                            ...                        ...           ...
# 2020-01-10                1.952383               1.747607e+13  43605.302282
# 2020-01-10                0.252569               1.747692e+13  25143.699270
# 2020-01-10                0.057612               1.747724e+13           NaN
# 2020-01-10                0.134937               1.747750e+13           NaN
# 2020-01-10                0.468656               1.747751e+13   8685.693099
#
#             Cumulative Daily P&L  Cumulative Daily Portfolio P&L     Yield
# Date
# 2019-03-27         -1.253234e+06                    99569.636686 -0.720047
# 2019-03-27         -4.899866e+06                    99569.636686 -0.722866
# 2019-03-27          1.244071e+06                    99569.636686  1.112337
# 2019-03-27          1.799837e+07                    99569.636686  8.382077
# 2019-03-27          1.604129e+07                    99569.636686  1.199976
# ...                          ...                             ...       ...
# 2020-01-10          2.739225e+07                    86826.035921  7.267550
# 2020-01-10          2.156141e+07                    86826.035921  0.598660
# 2020-01-10         -5.382023e+05                    86826.035921       NaN
# 2020-01-10          8.360253e+05                    86826.035921       NaN
# 2020-01-10          3.261122e+06                    86826.035921  1.737139
#
# [1664 rows x 24 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-651cb7a4ee01> in <module>
#      20     data_y1 = y1[y1.Ticker == ticker]
#      21     data_y2 = y2[y2.Ticker == ticker]
# ---> 22     ax1.scatter(data_y1[['Daily P&L']], data_y2[['Daily P&L']], label='%s year 1' % ticker, alpha=0.2)
#      23     #ax2.scatter(data_y2[['Daily P&L']], label='%s year 2' % ticker, alpha=0.2)
#      24
#
# D:\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# D:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size
